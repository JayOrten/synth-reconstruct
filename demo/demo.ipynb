# %%
import dawdreamer as daw
import numpy 
from scipy.io import wavfile
from pathlib import Path

# %% [markdown]
# Load DAWDreamer engine

# %%
engine = daw.RenderEngine(44100, 512)

# %%
engine.set_bpm(120.)

# %%
synth = engine.make_plugin_processor("synth", "C:\\Program Files\\Common Files\\VST3\\TAL-NoiseMaker.vst3\\Contents\\x86_64-win\\TAL-NoiseMaker.vst3")

# %% [markdown]
# Check initial parameters of synth

# %%
synth.get_parameters_description()
# Out:
# [{'index': 0,
#   'name': '-',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.5000000',
#   'currentValText': '0.5000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.5000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 1,
#   'name': 'Master Volume',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.4080000',
#   'currentValText': '0.4080000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.4999000132083893,
#   'defaultValueText': '0.4999000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 2,
#   'name': 'Filter Type',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 1.0,
#   'defaultValueText': '1.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 3,
#   'name': 'Filter Cutoff',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '1.0000000',
#   'currentValText': '1.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 1.0,
#   'defaultValueText': '1.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 4,
#   'name': 'Filter Resonance',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 5,
#   'name': 'Filter Keyfollow',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 6,
#   'name': 'Filter Contour',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.00',
#   'currentValText': '0.00',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.00',
#   'min': '-1.00',
#   'max': '1.00',
#   'valueStrings': []},
#  {'index': 7,
#   'name': 'Filter Attack',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 8,
#   'name': 'Filter Decay',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 9,
#   'name': 'Filter Sustain',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '1.0000000',
#   'currentValText': '1.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 1.0,
#   'defaultValueText': '1.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 10,
#   'name': 'Filter Release',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 11,
#   'name': 'Amp Attack',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 12,
#   'name': 'Amp Decay',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 13,
#   'name': 'Amp Sustain',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '1.0000000',
#   'currentValText': '1.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 1.0,
#   'defaultValueText': '1.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 14,
#   'name': 'Amp Release',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 15,
#   'name': 'Osc 1 Volume',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.8000000',
#   'currentValText': '0.8000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.800000011920929,
#   'defaultValueText': '0.8000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 16,
#   'name': 'Osc 2 Volume',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.800000011920929,
#   'defaultValueText': '0.8000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 17,
#   'name': 'Osc 3 Volume',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.8000000',
#   'currentValText': '0.8000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.800000011920929,
#   'defaultValueText': '0.8000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 18,
#   'name': 'Osc Mastertune',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.00 Semitones',
#   'currentValText': '0.00 Semitones',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.00 Semitones',
#   'min': '-0.50 Semitones',
#   'max': '0.50 Semitones',
#   'valueStrings': []},
#  {'index': 19,
#   'name': 'Osc 1 Tune',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '-12 Semitones',
#   'currentValText': '-12 Semitones',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0 Semitones',
#   'min': '-24 Semitones',
#   'max': '24 Semitones',
#   'valueStrings': []},
#  {'index': 20,
#   'name': 'Osc 2 Tune',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0 Semitones',
#   'currentValText': '0 Semitones',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0 Semitones',
#   'min': '-24 Semitones',
#   'max': '24 Semitones',
#   'valueStrings': []},
#  {'index': 21,
#   'name': 'Osc 1 Fine Tune',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.00 Semitones',
#   'currentValText': '0.00 Semitones',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.00 Semitones',
#   'min': '-0.50 Semitones',
#   'max': '0.50 Semitones',
#   'valueStrings': []},
#  {'index': 22,
#   'name': 'Osc 2 Fine Tune',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.00 Semitones',
#   'currentValText': '0.00 Semitones',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.00 Semitones',
#   'min': '-0.50 Semitones',
#   'max': '0.50 Semitones',
#   'valueStrings': []},
#  {'index': 23,
#   'name': 'Osc 1 Waveform',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 24,
#   'name': 'Osc 2 Waveform',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 25,
#   'name': 'Osc Sync',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 26,
#   'name': 'Lfo 1 Waveform',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 27,
#   'name': 'Lfo 2 Waveform',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 28,
#   'name': 'Lfo 1 Rate',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0116528 Hz',
#   'currentValText': '0.0116528 Hz',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.6000000238418579,
#   'defaultValueText': '0.0116528 Hz',
#   'min': '0.0116528 Hz',
#   'max': '0.0116528 Hz',
#   'valueStrings': []},
#  {'index': 29,
#   'name': 'Lfo 2 Rate',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0116528 Hz',
#   'currentValText': '0.0116528 Hz',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.6000000238418579,
#   'defaultValueText': '0.0116528 Hz',
#   'min': '0.0116528 Hz',
#   'max': '0.0116528 Hz',
#   'valueStrings': []},
#  {'index': 30,
#   'name': 'Lfo 1 Amount',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.00',
#   'currentValText': '0.00',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.00',
#   'min': '-1.00',
#   'max': '1.00',
#   'valueStrings': []},
#  {'index': 31,
#   'name': 'Lfo 2 Amount',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.00',
#   'currentValText': '0.00',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.00',
#   'min': '-1.00',
#   'max': '1.00',
#   'valueStrings': []},
#  {'index': 32,
#   'name': 'Lfo 1 Destination',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '-1.00',
#   'currentValText': '-1.00',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.00',
#   'min': '-1.00',
#   'max': '1.00',
#   'valueStrings': []},
#  {'index': 33,
#   'name': 'Lfo 2 Destination',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '-1.00',
#   'currentValText': '-1.00',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.00',
#   'min': '-1.00',
#   'max': '1.00',
#   'valueStrings': []},
#  {'index': 34,
#   'name': 'Lfo 1 Phase',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 35,
#   'name': 'Lfo 2 Phase',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 36,
#   'name': 'Osc 2 FM',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 37,
#   'name': 'Osc 2 Phase',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 38,
#   'name': 'Osc 1 PW',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.00',
#   'currentValText': '0.00',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.00',
#   'min': '-1.00',
#   'max': '1.00',
#   'valueStrings': []},
#  {'index': 39,
#   'name': 'Osc 1 Phase',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.5000000',
#   'currentValText': '0.5000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 40,
#   'name': 'Transpose',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0 Semitones',
#   'currentValText': '0 Semitones',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0 Semitones',
#   'min': '-12 Semitones',
#   'max': '24 Semitones',
#   'valueStrings': []},
#  {'index': 41,
#   'name': 'Free Ad Attack',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 42,
#   'name': 'Free Ad Decay',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.4000000059604645,
#   'defaultValueText': '0.4000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 43,
#   'name': 'Free Ad Amount',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '-1.00',
#   'currentValText': '-1.00',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.5,
#   'defaultValueText': '0.00',
#   'min': '-1.00',
#   'max': '1.00',
#   'valueStrings': []},
#  {'index': 44,
#   'name': 'Free Ad Destination',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 45,
#   'name': 'Lfo 1 Sync',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 46,
#   'name': 'Lfo 1 Keytrigger',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 47,
#   'name': 'Lfo 2 Sync',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 48,
#   'name': 'Lfo 2 Keytrigger',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 49,
#   'name': 'Portamento Amount',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 50,
#   'name': 'Portamento Mode',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 51,
#   'name': 'Voices',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 52,
#   'name': 'Velocity Volume',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 53,
#   'name': 'Velocity Contour',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 54,
#   'name': 'Velocity Filter',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 55,
#   'name': 'Pitchwheel Cutoff',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 56,
#   'name': 'Pitchwheel Pitch',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0',
#   'currentValText': '0.0',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0',
#   'min': '0.0',
#   'max': '12.0',
#   'valueStrings': []},
#  {'index': 57,
#   'name': 'Ringmodulation',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 58,
#   'name': 'Chorus 1 Enable',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 59,
#   'name': 'Chorus 2 Enable',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 60,
#   'name': 'Reverb Wet',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 61,
#   'name': 'Reverb Decay',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.5000000',
#   'currentValText': '0.5000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 62,
#   'name': 'Reverb Pre Delay',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 63,
#   'name': 'Reverb High Cut',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 64,
#   'name': 'Reverb Low Cut',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '1.0000000',
#   'currentValText': '1.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 65,
#   'name': 'Osc Bitcrusher',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '1.0000000',
#   'currentValText': '1.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 66,
#   'name': 'Master High Pass',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 67,
#   'name': 'Master Detune',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 68,
#   'name': 'Vintage Noise',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 69,
#   'name': 'Panic',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 70,
#   'name': 'MIDI LEARN',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 71,
#   'name': 'Envelope Destination',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 72,
#   'name': 'Envelope Speed',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 73,
#   'name': 'Envelope Amount',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 74,
#   'name': 'Envelope One Shot Mode',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 75,
#   'name': 'Envelope Fix Tempo',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 76,
#   'name': 'Envelope Reset',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 77,
#   'name': 'Filter Drive',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 78,
#   'name': 'Delay Wet',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 79,
#   'name': 'Delay Time',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.76 s',
#   'currentValText': '0.76 s',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.76 s',
#   'min': '0.76 s',
#   'max': '0.76 s',
#   'valueStrings': []},
#  {'index': 80,
#   'name': 'Delay Sync',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 81,
#   'name': 'Delay x2 L',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 82,
#   'name': 'Delay x2 R',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 83,
#   'name': 'Delay High Shelf',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 84,
#   'name': 'Delay Low Shelf',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 85,
#   'name': 'Delay Feedback',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.5000000',
#   'currentValText': '0.5000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 86,
#   'name': 'MIDI Clear',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 87,
#   'name': 'MIDI Lock',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000000',
#   'currentValText': '0.0000000',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000000',
#   'min': '0.0000000',
#   'max': '1.0000000',
#   'valueStrings': []},
#  {'index': 88,
#   'name': 'Bypass',
#   'numSteps': 2,
#   'isBoolean': False,
#   'isDiscrete': True,
#   'label': '',
#   'category': 'genericParameter',
#   'text': 'Off',
#   'currentValText': 'Off',
#   'isMetaParameter': False,
#   'isAutomatable': True,
#   'defaultValue': 0.0,
#   'defaultValueText': 'Off',
#   'min': 'Off',
#   'max': 'On',
#   'valueStrings': []},
#  {'index': 89,
#   'name': 'MIDI CC 0|0',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 90,
#   'name': 'MIDI CC 0|1',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 91,
#   'name': 'MIDI CC 0|2',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 92,
#   'name': 'MIDI CC 0|3',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 93,
#   'name': 'MIDI CC 0|4',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 94,
#   'name': 'MIDI CC 0|5',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 95,
#   'name': 'MIDI CC 0|6',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 96,
#   'name': 'MIDI CC 0|7',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 97,
#   'name': 'MIDI CC 0|8',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 98,
#   'name': 'MIDI CC 0|9',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 99,
#   'name': 'MIDI CC 0|10',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 100,
#   'name': 'MIDI CC 0|11',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 101,
#   'name': 'MIDI CC 0|12',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 102,
#   'name': 'MIDI CC 0|13',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 103,
#   'name': 'MIDI CC 0|14',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 104,
#   'name': 'MIDI CC 0|15',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 105,
#   'name': 'MIDI CC 0|16',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 106,
#   'name': 'MIDI CC 0|17',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 107,
#   'name': 'MIDI CC 0|18',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 108,
#   'name': 'MIDI CC 0|19',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 109,
#   'name': 'MIDI CC 0|20',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 110,
#   'name': 'MIDI CC 0|21',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 111,
#   'name': 'MIDI CC 0|22',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 112,
#   'name': 'MIDI CC 0|23',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 113,
#   'name': 'MIDI CC 0|24',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 114,
#   'name': 'MIDI CC 0|25',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 115,
#   'name': 'MIDI CC 0|26',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 116,
#   'name': 'MIDI CC 0|27',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 117,
#   'name': 'MIDI CC 0|28',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 118,
#   'name': 'MIDI CC 0|29',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 119,
#   'name': 'MIDI CC 0|30',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 120,
#   'name': 'MIDI CC 0|31',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 121,
#   'name': 'MIDI CC 0|32',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 122,
#   'name': 'MIDI CC 0|33',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
# ...
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 959,
#   'name': 'MIDI CC 6|90',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 960,
#   'name': 'MIDI CC 6|91',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 961,
#   'name': 'MIDI CC 6|92',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 962,
#   'name': 'MIDI CC 6|93',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 963,
#   'name': 'MIDI CC 6|94',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 964,
#   'name': 'MIDI CC 6|95',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 965,
#   'name': 'MIDI CC 6|96',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 966,
#   'name': 'MIDI CC 6|97',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 967,
#   'name': 'MIDI CC 6|98',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 968,
#   'name': 'MIDI CC 6|99',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 969,
#   'name': 'MIDI CC 6|100',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 970,
#   'name': 'MIDI CC 6|101',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 971,
#   'name': 'MIDI CC 6|102',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 972,
#   'name': 'MIDI CC 6|103',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 973,
#   'name': 'MIDI CC 6|104',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 974,
#   'name': 'MIDI CC 6|105',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 975,
#   'name': 'MIDI CC 6|106',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 976,
#   'name': 'MIDI CC 6|107',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 977,
#   'name': 'MIDI CC 6|108',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 978,
#   'name': 'MIDI CC 6|109',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 979,
#   'name': 'MIDI CC 6|110',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 980,
#   'name': 'MIDI CC 6|111',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 981,
#   'name': 'MIDI CC 6|112',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 982,
#   'name': 'MIDI CC 6|113',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 983,
#   'name': 'MIDI CC 6|114',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 984,
#   'name': 'MIDI CC 6|115',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 985,
#   'name': 'MIDI CC 6|116',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 986,
#   'name': 'MIDI CC 6|117',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 987,
#   'name': 'MIDI CC 6|118',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 988,
#   'name': 'MIDI CC 6|119',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 989,
#   'name': 'MIDI CC 6|120',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 990,
#   'name': 'MIDI CC 6|121',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 991,
#   'name': 'MIDI CC 6|122',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 992,
#   'name': 'MIDI CC 6|123',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 993,
#   'name': 'MIDI CC 6|124',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 994,
#   'name': 'MIDI CC 6|125',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 995,
#   'name': 'MIDI CC 6|126',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 996,
#   'name': 'MIDI CC 6|127',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 997,
#   'name': 'MIDI CC 6|128',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 998,
#   'name': 'MIDI CC 6|129',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  {'index': 999,
#   'name': 'MIDI CC 7|0',
#   'numSteps': 2147483647,
#   'isBoolean': False,
#   'isDiscrete': False,
#   'label': '',
#   'category': 'genericParameter',
#   'text': '0.0000',
#   'currentValText': '0.0000',
#   'isMetaParameter': False,
#   'isAutomatable': False,
#   'defaultValue': 0.0,
#   'defaultValueText': '0.0000',
#   'min': '0.0000',
#   'max': '1.0000',
#   'valueStrings': []},
#  ...]

# %%
def generate_preset(synth):
    # generate random float between 0 and 1, 88 times
    params = [numpy.random.rand() for _ in range(88)]
    print(params)
    # Set the parameters
    for i, param in enumerate(params):
        synth.set_parameter(i, param)
    return params

# %%
def export_sample(synth, preset_name):
    # (MIDI note, velocity, start sec, duration sec)
    synth.add_midi_note(60, 100, 0.0, 5.)
    engine.load_graph([
        (synth, [])
        ])
    engine.render(2.)
    audio = engine.get_audio()

    directory = Path('./samples/')
    directory.mkdir(parents=True, exist_ok=True)
    
    wavfile.write(directory / (preset_name + '.wav'), 44100, audio.transpose())

# %%
def export_preset(synth, num_to_generate=1):
    for i in range(num_to_generate):
        # Generate unique preset string
        preset_name = "preset_" + str(i)
        params = generate_preset(synth)

        # Save 'preset_name', and all params to one row in csv
        with open(f'presets.csv', 'a') as f:
            f.write(f'{preset_name},')
            for param in params:
                f.write(f'{param},')
            f.write('\n')
        
        # export sound
        export_sample(synth, preset_name)

# %%
export_preset(synth, 1)
# Out:
# [0.722775875019751, 0.7112535612220102, 0.6440045739554985, 0.18018767044008555, 0.18361321419164311, 0.6216355074405384, 0.9714999253591495, 0.49905459751659176, 0.620246427812481, 0.3259664886596213, 0.46317494703648976, 0.8025923025795162, 0.7326589377458778, 0.3499644026553905, 0.6444009229121779, 0.6794597807779187, 0.6723121897149165, 0.2262989221902123, 0.9213982083133936, 0.9578823082559613, 0.41856214679146897, 0.21337162522265252, 0.12708033493007187, 0.6650332107356125, 0.6712618627715723, 0.1461256457946638, 0.6570691321666927, 0.6048943213059145, 0.3309976213009166, 0.42653577137208465, 0.716951492216227, 0.38215073579283343, 0.8577173073564605, 0.2615696906652034, 0.8323192151467323, 0.8597195055838028, 0.00340782668553552, 0.11009622065469171, 0.7433265835230825, 0.11847586955445588, 0.2581808187523631, 0.5465058349879985, 0.4969128846849732, 0.26716270050381463, 0.2984457324582541, 0.10098400101654825, 0.7953258644282376, 0.3002532400515805, 0.3355365065070679, 0.056608794135713736, 0.13417588881658526, 0.19356055493083846, 0.5749540325443502, 0.7914497049221972, 0.7982421348631012, 0.9938946079168299, 0.012899759115764686, 0.01134355715961155, 0.14840303337742788, 0.4018448884485153, 0.4942542434238384, 0.3262319957487486, 0.3856176199057114, 0.8274971116028497, 0.8766709363346903, 0.15227808473627025, 0.07054216018766446, 0.4328311466353396, 0.919357417906077, 0.8807310395227026, 0.09549326560482785, 0.3232004844154803, 0.8385785523329672, 0.04847973486922419, 0.1495807721014265, 0.9430834307223525, 0.800395809075814, 0.07913633563971445, 0.2575095519894183, 0.08832044110969495, 0.9254167025307076, 0.5004160228931472, 0.9342686403939159, 0.7510029862898441, 0.010583215042024086, 0.6345692399430314, 0.8375630283902005, 0.2393823527237976]

# %%
def load_preset(synth, preset_name):
    with open(f'presets.csv', 'r') as f:
        for line in f:
            if line.startswith(preset_name):
                params = line.split(',')[1:]
                for i, param in enumerate(params):
                    # if param is new line, skip
                    if param == '\n':
                        continue
                    synth.set_parameter(i, float(param))

# %% [markdown]
# try to load a preset, save it out, to see if it matches generated file

# %%
load_preset(synth, 'preset_3')
export_sample(synth, 'test')
